# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('nursing_homes_quality.csv')
df
# Out:
#                                    Facility Name   PFI          Measure Code  \
# 0                          Bayberry Nursing Home  1073                   407
# 1                          Bayberry Nursing Home  1073                   408
# 2                          Bayberry Nursing Home  1073                   409
# 3                          Bayberry Nursing Home  1073                   410
# 4                  Bronxcare Special Care Center  4501                   409
# ...                                          ...   ...                   ...
# 363891  Yorktown Rehabilitation & Nursing Center  3630    NYNH_ResStatusComp
# 363892  Yorktown Rehabilitation & Nursing Center  3630  S_005_02_DTC_RS_RATE
# 363893  Yorktown Rehabilitation & Nursing Center  3630     S_013_02_OBS_RATE
# 363894  Yorktown Rehabilitation & Nursing Center  3630     S_038_02_ADJ_RATE
# 363895  Yorktown Rehabilitation & Nursing Center  3630     S_042_01_OBS_RATE
#
# ...
